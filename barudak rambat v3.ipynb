# %%
import pandas as pd
import numpy as np
import optuna
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve, auc
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline
import warnings
warnings.filterwarnings("ignore")

# %%
def create_features(data):
    data = data.copy()
    data['pernah_dihubungi_sebelumnya'] = np.where(data['hari_sejak_kontak_sebelumnya'] == 999, 0, 1)
    data['rasio_sukses_sebelumnya'] = (
        data['hasil_kampanye_sebelumnya'].map({'success': 1, 'failure': 0, 'nonexistent': 0}) * (data['jumlah_kontak_sebelumnya'] + 1)
    )
    data['risk_score'] = (
        0.4 * data['indeks_harga_konsumen'] +
        0.3 * data['suku_bunga_euribor_3bln'] +
        0.3 * data['tingkat_variasi_pekerjaan']
    )
    data['usia_group'] = pd.cut(data['usia'], bins=[18, 30, 45, 60, 100], labels=['muda', 'paruhbaya', 'senior', 'lansia'])
    data['beban_pinjaman'] = (
        data['pinjaman_rumah'].map({'yes': 1, 'no': 0, 'unknown': 0}) +
        data['pinjaman_pribadi'].map({'yes': 1, 'no': 0, 'unknown': 0})
    )
    return data

# %%
df = pd.read_csv("training_dataset.csv")
df = create_features(df)

target = "berlangganan_deposito"
features = [col for col in df.columns if col not in [target, "customer_number"]]
X = df[features]
y = df[target]

# === Preprocessing ===
NUM_FEATURES = ['usia', 'jumlah_kontak_kampanye_ini', 'indeks_harga_konsumen',
                'suku_bunga_euribor_3bln', 'rasio_sukses_sebelumnya', 'risk_score']
CAT_FEATURES = ['pekerjaan', 'status_perkawinan', 'pendidikan', 'jenis_kontak',
                'pulau', 'usia_group', 'pernah_dihubungi_sebelumnya']

preprocessor = ColumnTransformer([
    ("num", StandardScaler(), NUM_FEATURES),
    ("cat", OneHotEncoder(handle_unknown="ignore"), CAT_FEATURES)
])

# %%
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int("n_estimators", 100, 500),
        'max_depth': trial.suggest_int("max_depth", 3, 10),
        'learning_rate': trial.suggest_float("learning_rate", 0.01, 0.2),
        'subsample': trial.suggest_float("subsample", 0.5, 1.0),
        'colsample_bytree': trial.suggest_float("colsample_bytree", 0.5, 1.0),
        'scale_pos_weight': trial.suggest_float("scale_pos_weight", 1, 10),
        'random_state': 42,
        'tree_method': 'hist',
        'eval_metric': 'auc',
        'use_label_encoder': False,
    }

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    aucs = []

    for train_idx, valid_idx in skf.split(X, y):
        X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
        y_train, y_valid = y.iloc[train_idx], y.iloc[valid_idx]

        X_train_transformed = preprocessor.fit_transform(X_train)
        X_valid_transformed = preprocessor.transform(X_valid)

        smote = SMOTE(random_state=42)
        X_train_balanced, y_train_balanced = smote.fit_resample(X_train_transformed, y_train)

        clf = XGBClassifier(**params)
        clf.fit(X_train_balanced, y_train_balanced)

        y_pred = clf.predict_proba(X_valid_transformed)[:, 1]
        aucs.append(roc_auc_score(y_valid, y_pred))

    return np.mean(aucs)

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)
print("Best Trial:")
print(study.best_trial)
print("Best ROC-AUC:", study.best_value)
print("Best Parameters:", study.best_params)
# Out:
# [I 2025-05-26 14:34:35,160] A new study created in memory with name: no-name-b3ac7b4e-d576-45c3-aad4-c6ec3809b7a1
# [I 2025-05-26 14:34:40,714] Trial 0 finished with value: 0.7838546554154666 and parameters: {'n_estimators': 117, 'max_depth': 7, 'learning_rate': 0.11520234687200821, 'subsample': 0.5253710314498751, 'colsample_bytree': 0.6500575912258013, 'scale_pos_weight': 2.687908559780675}. Best is trial 0 with value: 0.7838546554154666.
# [I 2025-05-26 14:34:57,438] Trial 1 finished with value: 0.7856363879702145 and parameters: {'n_estimators': 439, 'max_depth': 7, 'learning_rate': 0.03127741835918094, 'subsample': 0.983816963631992, 'colsample_bytree': 0.8289343762989134, 'scale_pos_weight': 4.883619062262314}. Best is trial 1 with value: 0.7856363879702145.
# [I 2025-05-26 14:35:03,394] Trial 2 finished with value: 0.7852273787261053 and parameters: {'n_estimators': 268, 'max_depth': 3, 'learning_rate': 0.05147673896427619, 'subsample': 0.7652282606061291, 'colsample_bytree': 0.6565935886170708, 'scale_pos_weight': 1.8931473459570594}. Best is trial 1 with value: 0.7856363879702145.
# [I 2025-05-26 14:35:31,712] Trial 3 finished with value: 0.7481796261250118 and parameters: {'n_estimators': 265, 'max_depth': 9, 'learning_rate': 0.14389053324202628, 'subsample': 0.5516214281146636, 'colsample_bytree': 0.9511327385673227, 'scale_pos_weight': 5.7517224267475955}. Best is trial 1 with value: 0.7856363879702145.
# [I 2025-05-26 14:35:40,947] Trial 4 finished with value: 0.7862224906220887 and parameters: {'n_estimators': 194, 'max_depth': 6, 'learning_rate': 0.0689026782958145, 'subsample': 0.7941242009007808, 'colsample_bytree': 0.9642737211528123, 'scale_pos_weight': 3.367556822821091}. Best is trial 4 with value: 0.7862224906220887.
# [I 2025-05-26 14:35:48,129] Trial 5 finished with value: 0.7750325333472301 and parameters: {'n_estimators': 192, 'max_depth': 6, 'learning_rate': 0.1978558575982626, 'subsample': 0.9739962376776861, 'colsample_bytree': 0.8693088695112032, 'scale_pos_weight': 1.392112728481103}. Best is trial 4 with value: 0.7862224906220887.
# [I 2025-05-26 14:35:54,352] Trial 6 finished with value: 0.7856027944111561 and parameters: {'n_estimators': 303, 'max_depth': 3, 'learning_rate': 0.05252671761983358, 'subsample': 0.5457209611026116, 'colsample_bytree': 0.7319424887916743, 'scale_pos_weight': 3.936096805380938}. Best is trial 4 with value: 0.7862224906220887.
# [I 2025-05-26 14:36:04,647] Trial 7 finished with value: 0.785309412818455 and parameters: {'n_estimators': 484, 'max_depth': 3, 'learning_rate': 0.06966575999375668, 'subsample': 0.5773100383350647, 'colsample_bytree': 0.9542139159331298, 'scale_pos_weight': 7.496791549843795}. Best is trial 4 with value: 0.7862224906220887.
# [I 2025-05-26 14:36:11,259] Trial 8 finished with value: 0.7867975785894362 and parameters: {'n_estimators': 147, 'max_depth': 5, 'learning_rate': 0.0881491085792229, 'subsample': 0.5998814784659654, 'colsample_bytree': 0.9809735044864749, 'scale_pos_weight': 4.597763215422233}. Best is trial 8 with value: 0.7867975785894362.
# [I 2025-05-26 14:36:21,777] Trial 9 finished with value: 0.7767714184630646 and parameters: {'n_estimators': 146, 'max_depth': 9, 'learning_rate': 0.09239254288636974, 'subsample': 0.813900273604232, 'colsample_bytree': 0.6029991963110537, 'scale_pos_weight': 8.399974182408897}. Best is trial 8 with value: 0.7867975785894362.
# [I 2025-05-26 14:36:33,873] Trial 10 finished with value: 0.7647088379529265 and parameters: {'n_estimators': 367, 'max_depth': 5, 'learning_rate': 0.14766283173566672, 'subsample': 0.6682514122828163, 'colsample_bytree': 0.8083148147851266, 'scale_pos_weight': 6.428351981815828}. Best is trial 8 with value: 0.7867975785894362.
# [I 2025-05-26 14:36:40,872] Trial 11 finished with value: 0.7860559063633976 and parameters: {'n_estimators': 190, 'max_depth': 5, 'learning_rate': 0.010768445144867314, 'subsample': 0.6858288671407199, 'colsample_bytree': 0.9793726458644986, 'scale_pos_weight': 3.8214757350120747}. Best is trial 8 with value: 0.7867975785894362.
# [I 2025-05-26 14:36:47,013] Trial 12 finished with value: 0.7882535090091949 and parameters: {'n_estimators': 201, 'max_depth': 5, 'learning_rate': 0.09261194222963855, 'subsample': 0.8613079206548941, 'colsample_bytree': 0.9029450226643254, 'scale_pos_weight': 3.495513648764413}. Best is trial 12 with value: 0.7882535090091949.
# [I 2025-05-26 14:36:50,782] Trial 13 finished with value: 0.7865415074467339 and parameters: {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.11031700444714283, 'subsample': 0.8890597980781954, 'colsample_bytree': 0.514154026506132, 'scale_pos_weight': 9.412941630305586}. Best is trial 12 with value: 0.7882535090091949.
# [I 2025-05-26 14:36:56,839] Trial 14 finished with value: 0.7858949431770809 and parameters: {'n_estimators': 222, 'max_depth': 4, 'learning_rate': 0.1383552622859881, 'subsample': 0.8860925875638614, 'colsample_bytree': 0.872338936062582, 'scale_pos_weight': 4.764905233154358}. Best is trial 12 with value: 0.7882535090091949.
# [I 2025-05-26 14:37:19,288] Trial 15 finished with value: 0.7620334796068036 and parameters: {'n_estimators': 326, 'max_depth': 8, 'learning_rate': 0.0890681986326568, 'subsample': 0.6553977297359919, 'colsample_bytree': 0.8918087547312912, 'scale_pos_weight': 6.454938502611723}. Best is trial 12 with value: 0.7882535090091949.
# [I 2025-05-26 14:37:23,888] Trial 16 finished with value: 0.7874976013703263 and parameters: {'n_estimators': 152, 'max_depth': 4, 'learning_rate': 0.18396817526470893, 'subsample': 0.8692052519285547, 'colsample_bytree': 0.7578780218887254, 'scale_pos_weight': 2.781292729177376}. Best is trial 12 with value: 0.7882535090091949.
# [I 2025-05-26 14:37:30,502] Trial 17 finished with value: 0.7839401180925447 and parameters: {'n_estimators': 244, 'max_depth': 4, 'learning_rate': 0.1917071499073381, 'subsample': 0.8850882016477439, 'colsample_bytree': 0.7535680625468787, 'scale_pos_weight': 2.5834845691650012}. Best is trial 12 with value: 0.7882535090091949.
# [I 2025-05-26 14:37:34,693] Trial 18 finished with value: 0.7884018580697585 and parameters: {'n_estimators': 157, 'max_depth': 4, 'learning_rate': 0.17109214554005708, 'subsample': 0.8343629200847531, 'colsample_bytree': 0.7427231532894414, 'scale_pos_weight': 2.72383815139395}. Best is trial 18 with value: 0.7884018580697585.
# [I 2025-05-26 14:38:05,049] Trial 19 finished with value: 0.7480938566898769 and parameters: {'n_estimators': 361, 'max_depth': 10, 'learning_rate': 0.16813758858884353, 'subsample': 0.7311140563085164, 'colsample_bytree': 0.7053604028838941, 'scale_pos_weight': 1.0181582396788853}. Best is trial 18 with value: 0.7884018580697585.
# [I 2025-05-26 14:38:12,917] Trial 20 finished with value: 0.7796560955923247 and parameters: {'n_estimators': 223, 'max_depth': 6, 'learning_rate': 0.12215281208661703, 'subsample': 0.9308201570524693, 'colsample_bytree': 0.7939920125352704, 'scale_pos_weight': 2.0358625760713815}. Best is trial 18 with value: 0.7884018580697585.
# [I 2025-05-26 14:38:17,258] Trial 21 finished with value: 0.7875883228077527 and parameters: {'n_estimators': 158, 'max_depth': 4, 'learning_rate': 0.17101623475592717, 'subsample': 0.8373917313348096, 'colsample_bytree': 0.7644629409624493, 'scale_pos_weight': 3.076067387957764}. Best is trial 18 with value: 0.7884018580697585.
# [I 2025-05-26 14:38:21,465] Trial 22 finished with value: 0.7867712069459066 and parameters: {'n_estimators': 157, 'max_depth': 4, 'learning_rate': 0.16555175128798336, 'subsample': 0.824821007430152, 'colsample_bytree': 0.6752080911762065, 'scale_pos_weight': 3.4042082129412985}. Best is trial 18 with value: 0.7884018580697585.
# [I 2025-05-26 14:38:25,938] Trial 23 finished with value: 0.7881476754128254 and parameters: {'n_estimators': 179, 'max_depth': 4, 'learning_rate': 0.16711088479912878, 'subsample': 0.8438390860316766, 'colsample_bytree': 0.6021173335063839, 'scale_pos_weight': 4.065984863360004}. Best is trial 18 with value: 0.7884018580697585.
# [I 2025-05-26 14:38:31,456] Trial 24 finished with value: 0.7858683896939693 and parameters: {'n_estimators': 208, 'max_depth': 5, 'learning_rate': 0.1352573415485397, 'subsample': 0.942363509287371, 'colsample_bytree': 0.5475790535064693, 'scale_pos_weight': 4.38668068122063}. Best is trial 18 with value: 0.7884018580697585.
# [I 2025-05-26 14:38:36,193] Trial 25 finished with value: 0.7876261086852565 and parameters: {'n_estimators': 247, 'max_depth': 3, 'learning_rate': 0.15418861702594847, 'subsample': 0.7421397427096074, 'colsample_bytree': 0.6135828698729627, 'scale_pos_weight': 5.269675688753162}. Best is trial 18 with value: 0.7884018580697585.
# [I 2025-05-26 14:38:39,765] Trial 26 finished with value: 0.790625261645583 and parameters: {'n_estimators': 125, 'max_depth': 4, 'learning_rate': 0.1790144495231766, 'subsample': 0.7789089127182841, 'colsample_bytree': 0.578513451749137, 'scale_pos_weight': 2.1383553851104162}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:38:44,807] Trial 27 finished with value: 0.7863477881200446 and parameters: {'n_estimators': 120, 'max_depth': 6, 'learning_rate': 0.1266712019538221, 'subsample': 0.788940928334067, 'colsample_bytree': 0.9127398064714229, 'scale_pos_weight': 2.022555958343962}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:38:48,981] Trial 28 finished with value: 0.7857649409251131 and parameters: {'n_estimators': 126, 'max_depth': 5, 'learning_rate': 0.1806717886619214, 'subsample': 0.711150539880466, 'colsample_bytree': 0.5675620810315384, 'scale_pos_weight': 1.653025536253111}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:38:54,181] Trial 29 finished with value: 0.7886271396547763 and parameters: {'n_estimators': 111, 'max_depth': 7, 'learning_rate': 0.1038197241535165, 'subsample': 0.9237393332798913, 'colsample_bytree': 0.8378892905149097, 'scale_pos_weight': 2.333932902798857}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:39:00,039] Trial 30 finished with value: 0.7864123062960462 and parameters: {'n_estimators': 102, 'max_depth': 8, 'learning_rate': 0.10850378714537645, 'subsample': 0.9247641507388404, 'colsample_bytree': 0.8302178911887313, 'scale_pos_weight': 2.5820461843749007}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:39:06,400] Trial 31 finished with value: 0.7862942385285938 and parameters: {'n_estimators': 135, 'max_depth': 7, 'learning_rate': 0.10353294354141179, 'subsample': 0.8529341256144884, 'colsample_bytree': 0.8489341173853782, 'scale_pos_weight': 2.399713801344348}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:39:14,082] Trial 32 finished with value: 0.7862438011667937 and parameters: {'n_estimators': 170, 'max_depth': 7, 'learning_rate': 0.07363293667155445, 'subsample': 0.9032753221777864, 'colsample_bytree': 0.9285872794642299, 'scale_pos_weight': 3.5796175734709355}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:39:19,513] Trial 33 finished with value: 0.7893318046286464 and parameters: {'n_estimators': 128, 'max_depth': 7, 'learning_rate': 0.09887170349157148, 'subsample': 0.7745333345948548, 'colsample_bytree': 0.701893924123297, 'scale_pos_weight': 1.002423239860329}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:39:25,601] Trial 34 finished with value: 0.7848665162353721 and parameters: {'n_estimators': 115, 'max_depth': 8, 'learning_rate': 0.12374434595677808, 'subsample': 0.7827318559962274, 'colsample_bytree': 0.6993048406454804, 'scale_pos_weight': 1.2008558699691119}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:39:31,588] Trial 35 finished with value: 0.7769233041057682 and parameters: {'n_estimators': 119, 'max_depth': 7, 'learning_rate': 0.15779134792372015, 'subsample': 0.5003304826579045, 'colsample_bytree': 0.6443221988389706, 'scale_pos_weight': 1.6449337469298633}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:39:40,153] Trial 36 finished with value: 0.7883253954475646 and parameters: {'n_estimators': 134, 'max_depth': 8, 'learning_rate': 0.05420927407963651, 'subsample': 0.9972503132981771, 'colsample_bytree': 0.7834707336883513, 'scale_pos_weight': 2.0146006334942745}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:39:44,871] Trial 37 finished with value: 0.7894406935219627 and parameters: {'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.07916117452482066, 'subsample': 0.7616770876535993, 'colsample_bytree': 0.7261966385350637, 'scale_pos_weight': 1.0031994007801002}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:39:59,777] Trial 38 finished with value: 0.7802102314652493 and parameters: {'n_estimators': 424, 'max_depth': 6, 'learning_rate': 0.07468646612955462, 'subsample': 0.7599003976694985, 'colsample_bytree': 0.7116136643755202, 'scale_pos_weight': 1.5680300348384768}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:40:06,246] Trial 39 finished with value: 0.789531217488569 and parameters: {'n_estimators': 112, 'max_depth': 9, 'learning_rate': 0.0377375732094162, 'subsample': 0.6428765858197878, 'colsample_bytree': 0.6658346594526781, 'scale_pos_weight': 1.029653284687616}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:40:24,461] Trial 40 finished with value: 0.7851876779542734 and parameters: {'n_estimators': 287, 'max_depth': 10, 'learning_rate': 0.03915370635924391, 'subsample': 0.6306867490558803, 'colsample_bytree': 0.6452713784879281, 'scale_pos_weight': 1.1769764111878822}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:40:32,941] Trial 41 finished with value: 0.7880994593645252 and parameters: {'n_estimators': 103, 'max_depth': 9, 'learning_rate': 0.01795427148304887, 'subsample': 0.7058186062194729, 'colsample_bytree': 0.67968705268736, 'scale_pos_weight': 1.0739620181513252}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:40:41,818] Trial 42 finished with value: 0.7894039850131527 and parameters: {'n_estimators': 131, 'max_depth': 9, 'learning_rate': 0.0397502610341854, 'subsample': 0.6211173458580942, 'colsample_bytree': 0.7225695038003652, 'scale_pos_weight': 2.2892949818657993}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:40:52,945] Trial 43 finished with value: 0.7902897064464829 and parameters: {'n_estimators': 172, 'max_depth': 9, 'learning_rate': 0.035403405121593026, 'subsample': 0.6100052187286752, 'colsample_bytree': 0.7295884238892417, 'scale_pos_weight': 1.6031843279840103}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:41:03,668] Trial 44 finished with value: 0.7898006482463511 and parameters: {'n_estimators': 170, 'max_depth': 9, 'learning_rate': 0.03449539930274483, 'subsample': 0.610662125327147, 'colsample_bytree': 0.7290864839841816, 'scale_pos_weight': 1.7235377336144118}. Best is trial 26 with value: 0.790625261645583.
# [I 2025-05-26 14:41:15,365] Trial 45 finished with value: 0.7921765137964016 and parameters: {'n_estimators': 177, 'max_depth': 10, 'learning_rate': 0.02538053172551917, 'subsample': 0.5772826943342921, 'colsample_bytree': 0.6238322230230076, 'scale_pos_weight': 1.5888466413357527}. Best is trial 45 with value: 0.7921765137964016.
# [I 2025-05-26 14:41:27,651] Trial 46 finished with value: 0.7916968035972849 and parameters: {'n_estimators': 185, 'max_depth': 10, 'learning_rate': 0.02613623242080819, 'subsample': 0.5624185502528971, 'colsample_bytree': 0.5720516532681454, 'scale_pos_weight': 3.0246071612908043}. Best is trial 45 with value: 0.7921765137964016.
# [I 2025-05-26 14:41:39,317] Trial 47 finished with value: 0.7925132383064402 and parameters: {'n_estimators': 173, 'max_depth': 10, 'learning_rate': 0.023892138919340458, 'subsample': 0.5636075133536317, 'colsample_bytree': 0.5775999022859863, 'scale_pos_weight': 3.139530601835282}. Best is trial 47 with value: 0.7925132383064402.
# [I 2025-05-26 14:41:50,393] Trial 48 finished with value: 0.7915522504574801 and parameters: {'n_estimators': 184, 'max_depth': 10, 'learning_rate': 0.023389368000184842, 'subsample': 0.5801269338192796, 'colsample_bytree': 0.5079805807144664, 'scale_pos_weight': 4.079575798442343}. Best is trial 47 with value: 0.7925132383064402.
# [I 2025-05-26 14:42:03,757] Trial 49 finished with value: 0.7919405208793112 and parameters: {'n_estimators': 233, 'max_depth': 10, 'learning_rate': 0.022500743846178072, 'subsample': 0.5768299735239245, 'colsample_bytree': 0.5096513489837615, 'scale_pos_weight': 4.260834149639663}. Best is trial 47 with value: 0.7925132383064402.
# [I 2025-05-26 14:42:17,376] Trial 50 finished with value: 0.7917989609843936 and parameters: {'n_estimators': 232, 'max_depth': 10, 'learning_rate': 0.02045693830190174, 'subsample': 0.5712228932758817, 'colsample_bytree': 0.5001251723893443, 'scale_pos_weight': 5.537130534771169}. Best is trial 47 with value: 0.7925132383064402.
# [I 2025-05-26 14:42:30,849] Trial 51 finished with value: 0.7908180145723553 and parameters: {'n_estimators': 221, 'max_depth': 10, 'learning_rate': 0.021905786390148, 'subsample': 0.5737576131128793, 'colsample_bytree': 0.5020794943494923, 'scale_pos_weight': 5.827647365653916}. Best is trial 47 with value: 0.7925132383064402.
# [I 2025-05-26 14:42:44,946] Trial 52 finished with value: 0.7891770000483879 and parameters: {'n_estimators': 244, 'max_depth': 10, 'learning_rate': 0.024369125458558127, 'subsample': 0.5455318717880392, 'colsample_bytree': 0.5319122630466411, 'scale_pos_weight': 5.150907483448593}. Best is trial 47 with value: 0.7925132383064402.
# [I 2025-05-26 14:43:02,331] Trial 53 finished with value: 0.7935884915001374 and parameters: {'n_estimators': 268, 'max_depth': 10, 'learning_rate': 0.01314236096391534, 'subsample': 0.5853773809912333, 'colsample_bytree': 0.5323247277151291, 'scale_pos_weight': 4.37208198549502}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:43:19,986] Trial 54 finished with value: 0.7928055263155018 and parameters: {'n_estimators': 268, 'max_depth': 10, 'learning_rate': 0.01230810343041846, 'subsample': 0.5156736713833651, 'colsample_bytree': 0.5298268253889369, 'scale_pos_weight': 5.761215266209608}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:43:38,542] Trial 55 finished with value: 0.792125712196213 and parameters: {'n_estimators': 267, 'max_depth': 10, 'learning_rate': 0.011596438634527315, 'subsample': 0.5241225974955099, 'colsample_bytree': 0.5346385081609577, 'scale_pos_weight': 6.057340742003111}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:43:58,321] Trial 56 finished with value: 0.7917390718673181 and parameters: {'n_estimators': 302, 'max_depth': 10, 'learning_rate': 0.011613280358488066, 'subsample': 0.5201873556239857, 'colsample_bytree': 0.5362785345793701, 'scale_pos_weight': 6.291801518279213}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:44:21,985] Trial 57 finished with value: 0.7693932851168431 and parameters: {'n_estimators': 283, 'max_depth': 10, 'learning_rate': 0.05334987842789882, 'subsample': 0.5316552132958687, 'colsample_bytree': 0.5539058683107003, 'scale_pos_weight': 7.196719600097124}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:44:42,899] Trial 58 finished with value: 0.7779933266266392 and parameters: {'n_estimators': 323, 'max_depth': 9, 'learning_rate': 0.04719836517046703, 'subsample': 0.5935403393815291, 'colsample_bytree': 0.5239219676185247, 'scale_pos_weight': 4.434733614925167}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:45:02,759] Trial 59 finished with value: 0.7908179909173995 and parameters: {'n_estimators': 265, 'max_depth': 9, 'learning_rate': 0.010866250705494757, 'subsample': 0.5017774455112475, 'colsample_bytree': 0.5883139726662202, 'scale_pos_weight': 7.007540866311642}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:45:35,172] Trial 60 finished with value: 0.7651968832369682 and parameters: {'n_estimators': 324, 'max_depth': 10, 'learning_rate': 0.05975605299162835, 'subsample': 0.5317415237199716, 'colsample_bytree': 0.6297333947273002, 'scale_pos_weight': 4.911046123223539}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:45:52,102] Trial 61 finished with value: 0.789493888435967 and parameters: {'n_estimators': 235, 'max_depth': 10, 'learning_rate': 0.028822988254948233, 'subsample': 0.5550214088141607, 'colsample_bytree': 0.549924872468028, 'scale_pos_weight': 5.721814600658037}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:46:09,873] Trial 62 finished with value: 0.7920782111530388 and parameters: {'n_estimators': 270, 'max_depth': 10, 'learning_rate': 0.017011569890222605, 'subsample': 0.581661970088709, 'colsample_bytree': 0.5226738546390232, 'scale_pos_weight': 6.017048640028364}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:46:29,787] Trial 63 finished with value: 0.7915235500648411 and parameters: {'n_estimators': 264, 'max_depth': 10, 'learning_rate': 0.016068225173035727, 'subsample': 0.5905802119774103, 'colsample_bytree': 0.5592397611492621, 'scale_pos_weight': 6.166165362007899}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:46:49,437] Trial 64 finished with value: 0.783632942440456 and parameters: {'n_estimators': 287, 'max_depth': 10, 'learning_rate': 0.029690545874497237, 'subsample': 0.5216351848705278, 'colsample_bytree': 0.5197828030661412, 'scale_pos_weight': 6.6882715958386125}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:47:02,527] Trial 65 finished with value: 0.782064441546211 and parameters: {'n_estimators': 210, 'max_depth': 9, 'learning_rate': 0.041391950242520834, 'subsample': 0.5389678595877849, 'colsample_bytree': 0.5968579918067601, 'scale_pos_weight': 7.854845196753807}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:47:23,495] Trial 66 finished with value: 0.79153082819407 and parameters: {'n_estimators': 256, 'max_depth': 10, 'learning_rate': 0.01557008704595767, 'subsample': 0.6756581569407708, 'colsample_bytree': 0.538560456848164, 'scale_pos_weight': 6.014720881983701}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:47:49,821] Trial 67 finished with value: 0.7752442985641068 and parameters: {'n_estimators': 278, 'max_depth': 10, 'learning_rate': 0.04522598789104601, 'subsample': 0.5556326376783195, 'colsample_bytree': 0.6220936882367378, 'scale_pos_weight': 5.188147266898257}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:48:05,985] Trial 68 finished with value: 0.7855946985636784 and parameters: {'n_estimators': 312, 'max_depth': 9, 'learning_rate': 0.031045837738540142, 'subsample': 0.5132266844814021, 'colsample_bytree': 0.5873510764173404, 'scale_pos_weight': 4.746893308641734}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:48:26,616] Trial 69 finished with value: 0.7932453768456 and parameters: {'n_estimators': 343, 'max_depth': 10, 'learning_rate': 0.011090223197152964, 'subsample': 0.6468891625545314, 'colsample_bytree': 0.5667664641754572, 'scale_pos_weight': 3.8054188149118473}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:48:50,921] Trial 70 finished with value: 0.7920248619483664 and parameters: {'n_estimators': 389, 'max_depth': 10, 'learning_rate': 0.01401072990692189, 'subsample': 0.6413950369161447, 'colsample_bytree': 0.5613781987520319, 'scale_pos_weight': 3.7870112921203596}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:49:19,673] Trial 71 finished with value: 0.7909224188143374 and parameters: {'n_estimators': 344, 'max_depth': 10, 'learning_rate': 0.01146866738821399, 'subsample': 0.6506226003108679, 'colsample_bytree': 0.5666252293689834, 'scale_pos_weight': 6.619490076149947}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:49:44,858] Trial 72 finished with value: 0.7904868968899186 and parameters: {'n_estimators': 402, 'max_depth': 10, 'learning_rate': 0.01774762017306051, 'subsample': 0.6043283246696087, 'colsample_bytree': 0.5430532847615006, 'scale_pos_weight': 3.7508380969851753}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:50:05,561] Trial 73 finished with value: 0.791845793171382 and parameters: {'n_estimators': 374, 'max_depth': 10, 'learning_rate': 0.01676396112517767, 'subsample': 0.6243478242510209, 'colsample_bytree': 0.5234603359668969, 'scale_pos_weight': 3.107861195183945}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:50:30,678] Trial 74 finished with value: 0.7914879648778079 and parameters: {'n_estimators': 495, 'max_depth': 9, 'learning_rate': 0.01075273033490394, 'subsample': 0.590124864080039, 'colsample_bytree': 0.6054485672209335, 'scale_pos_weight': 5.450104906673755}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:50:58,721] Trial 75 finished with value: 0.7797660548292331 and parameters: {'n_estimators': 347, 'max_depth': 10, 'learning_rate': 0.02860034321492473, 'subsample': 0.6421956583507918, 'colsample_bytree': 0.5782810542358301, 'scale_pos_weight': 9.873346266723402}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:51:35,064] Trial 76 finished with value: 0.7806044444016753 and parameters: {'n_estimators': 413, 'max_depth': 9, 'learning_rate': 0.034214547396139765, 'subsample': 0.5474682063380405, 'colsample_bytree': 0.558036245240894, 'scale_pos_weight': 3.2789321739359734}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:52:14,558] Trial 77 finished with value: 0.76677917891347 and parameters: {'n_estimators': 390, 'max_depth': 10, 'learning_rate': 0.060333578980210203, 'subsample': 0.66372277310535, 'colsample_bytree': 0.5308781207895614, 'scale_pos_weight': 3.777354880533243}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:53:08,309] Trial 78 finished with value: 0.7898187218800212 and parameters: {'n_estimators': 466, 'max_depth': 9, 'learning_rate': 0.015718993924957236, 'subsample': 0.6931731289657246, 'colsample_bytree': 0.6286746954295359, 'scale_pos_weight': 4.501598616135605}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:53:39,112] Trial 79 finished with value: 0.7891477117647641 and parameters: {'n_estimators': 311, 'max_depth': 8, 'learning_rate': 0.025211858708893656, 'subsample': 0.5679727189576335, 'colsample_bytree': 0.58807301662095, 'scale_pos_weight': 4.860514612683178}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:54:01,140] Trial 80 finished with value: 0.7858509575891995 and parameters: {'n_estimators': 197, 'max_depth': 10, 'learning_rate': 0.04476853199720463, 'subsample': 0.5841197258202864, 'colsample_bytree': 0.5669530620601867, 'scale_pos_weight': 3.543918718548176}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:54:29,732] Trial 81 finished with value: 0.79189202247655 and parameters: {'n_estimators': 276, 'max_depth': 10, 'learning_rate': 0.02076278958679284, 'subsample': 0.510148563795264, 'colsample_bytree': 0.513071531374884, 'scale_pos_weight': 4.187745064745932}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:55:02,250] Trial 82 finished with value: 0.7918415957825449 and parameters: {'n_estimators': 256, 'max_depth': 10, 'learning_rate': 0.02412362553703519, 'subsample': 0.5373431167704561, 'colsample_bytree': 0.5474552853745526, 'scale_pos_weight': 4.179152010135198}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:55:34,543] Trial 83 finished with value: 0.7871806260864121 and parameters: {'n_estimators': 297, 'max_depth': 10, 'learning_rate': 0.03262073046515473, 'subsample': 0.6157677855223903, 'colsample_bytree': 0.523094474057544, 'scale_pos_weight': 2.9133063578068676}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:56:00,456] Trial 84 finished with value: 0.7923081293710009 and parameters: {'n_estimators': 212, 'max_depth': 10, 'learning_rate': 0.013994790716404863, 'subsample': 0.5603896631778595, 'colsample_bytree': 0.5143385968548576, 'scale_pos_weight': 3.8780121489689203}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:56:20,340] Trial 85 finished with value: 0.7919573805207457 and parameters: {'n_estimators': 209, 'max_depth': 9, 'learning_rate': 0.015351093936066247, 'subsample': 0.5595120578369548, 'colsample_bytree': 0.5405060192890616, 'scale_pos_weight': 3.9256323391844}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:57:01,179] Trial 86 finished with value: 0.7931922810123335 and parameters: {'n_estimators': 356, 'max_depth': 10, 'learning_rate': 0.010628022913458017, 'subsample': 0.5228951218685787, 'colsample_bytree': 0.571704047532545, 'scale_pos_weight': 3.2475510175381945}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:57:51,166] Trial 87 finished with value: 0.7893325215227673 and parameters: {'n_estimators': 340, 'max_depth': 10, 'learning_rate': 0.020356185447044612, 'subsample': 0.5269074271059802, 'colsample_bytree': 0.5787380874078635, 'scale_pos_weight': 3.196755085966266}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:58:20,948] Trial 88 finished with value: 0.7921081137439376 and parameters: {'n_estimators': 355, 'max_depth': 9, 'learning_rate': 0.010770030832658914, 'subsample': 0.5456830246376156, 'colsample_bytree': 0.6067227831123195, 'scale_pos_weight': 2.803842130431056}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:58:50,256] Trial 89 finished with value: 0.791700113741012 and parameters: {'n_estimators': 355, 'max_depth': 9, 'learning_rate': 0.01080397160416713, 'subsample': 0.5435140598812455, 'colsample_bytree': 0.6189654452870462, 'scale_pos_weight': 2.664484830900967}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:59:27,949] Trial 90 finished with value: 0.7842578449605637 and parameters: {'n_estimators': 374, 'max_depth': 10, 'learning_rate': 0.027118237832429237, 'subsample': 0.5118942171661848, 'colsample_bytree': 0.5978225596564823, 'scale_pos_weight': 3.552035884902049}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 14:59:57,264] Trial 91 finished with value: 0.7914269755089158 and parameters: {'n_estimators': 333, 'max_depth': 10, 'learning_rate': 0.019856409638818615, 'subsample': 0.5655518443401862, 'colsample_bytree': 0.5311807162633784, 'scale_pos_weight': 3.3678886845363474}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 15:00:26,808] Trial 92 finished with value: 0.7926934169039141 and parameters: {'n_estimators': 295, 'max_depth': 10, 'learning_rate': 0.010589681246825508, 'subsample': 0.5534142998965954, 'colsample_bytree': 0.5759608008453039, 'scale_pos_weight': 2.9043856978584337}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 15:00:58,287] Trial 93 finished with value: 0.7917727487483108 and parameters: {'n_estimators': 294, 'max_depth': 10, 'learning_rate': 0.011242774998929672, 'subsample': 0.5499971737170388, 'colsample_bytree': 0.6370300155865127, 'scale_pos_weight': 2.8523521821459337}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 15:01:23,427] Trial 94 finished with value: 0.7887339899813043 and parameters: {'n_estimators': 312, 'max_depth': 9, 'learning_rate': 0.025861799255103967, 'subsample': 0.5989786978921623, 'colsample_bytree': 0.6055993931100242, 'scale_pos_weight': 2.4430611118776104}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 15:02:01,436] Trial 95 finished with value: 0.788340547909357 and parameters: {'n_estimators': 361, 'max_depth': 10, 'learning_rate': 0.02044250107195323, 'subsample': 0.5229739831709894, 'colsample_bytree': 0.6592335273874123, 'scale_pos_weight': 2.773146578696522}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 15:02:20,967] Trial 96 finished with value: 0.7875984388010986 and parameters: {'n_estimators': 144, 'max_depth': 10, 'learning_rate': 0.010281505257902494, 'subsample': 0.5003823192021423, 'colsample_bytree': 0.5513362952733663, 'scale_pos_weight': 3.3646228710971733}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 15:02:42,926] Trial 97 finished with value: 0.7918425998206174 and parameters: {'n_estimators': 218, 'max_depth': 9, 'learning_rate': 0.031340882354964586, 'subsample': 0.533901819245828, 'colsample_bytree': 0.5864155109700474, 'scale_pos_weight': 2.184298081394327}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 15:03:13,994] Trial 98 finished with value: 0.7926426554442194 and parameters: {'n_estimators': 251, 'max_depth': 10, 'learning_rate': 0.01535347557495739, 'subsample': 0.8088445173745253, 'colsample_bytree': 0.574399648595972, 'scale_pos_weight': 2.5382751182695498}. Best is trial 53 with value: 0.7935884915001374.
# [I 2025-05-26 15:03:44,616] Trial 99 finished with value: 0.787016171986272 and parameters: {'n_estimators': 254, 'max_depth': 10, 'learning_rate': 0.03718911156049485, 'subsample': 0.7254180239134741, 'colsample_bytree': 0.576252837105464, 'scale_pos_weight': 2.5021148560540567}. Best is trial 53 with value: 0.7935884915001374.
# Best Trial:
# FrozenTrial(number=53, state=TrialState.COMPLETE, values=[0.7935884915001374], datetime_start=datetime.datetime(2025, 5, 26, 14, 42, 44, 948534), datetime_complete=datetime.datetime(2025, 5, 26, 14, 43, 2, 330857), params={'n_estimators': 268, 'max_depth': 10, 'learning_rate': 0.01314236096391534, 'subsample': 0.5853773809912333, 'colsample_bytree': 0.5323247277151291, 'scale_pos_weight': 4.37208198549502}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'n_estimators': IntDistribution(high=500, log=False, low=100, step=1), 'max_depth': IntDistribution(high=10, log=False, low=3, step=1), 'learning_rate': FloatDistribution(high=0.2, log=False, low=0.01, step=None), 'subsample': FloatDistribution(high=1.0, log=False, low=0.5, step=None), 'colsample_bytree': FloatDistribution(high=1.0, log=False, low=0.5, step=None), 'scale_pos_weight': FloatDistribution(high=10.0, log=False, low=1.0, step=None)}, trial_id=53, value=None)
# Best ROC-AUC: 0.7935884915001374
# Best Parameters: {'n_estimators': 268, 'max_depth': 10, 'learning_rate': 0.01314236096391534, 'subsample': 0.5853773809912333, 'colsample_bytree': 0.5323247277151291, 'scale_pos_weight': 4.37208198549502}

# %%
best_params = study.best_params
best_params.update({'tree_method': 'hist', 'use_label_encoder': False, 'random_state': 42, 'eval_metric': 'auc'})

final_model = ImbPipeline([
    ("preprocess", preprocessor),
    ("smote", SMOTE(random_state=42)),
    ("clf", XGBClassifier(**best_params))
])
final_model.fit(X, y)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['usia',
#                                                    'jumlah_kontak_kampanye_ini',
#                                                    'indeks_harga_konsumen',
#                                                    'suku_bunga_euribor_3bln',
#                                                    'rasio_sukses_sebelumnya',
#                                                    'risk_score']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['pekerjaan',
#                                                    'status_perkawinan',
#                                                    'pendidikan', 'jenis_kontak',
#                                                    'pulau', 'usia_group',
#                                                    'pernah_...
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None,
#                                learning_rate=0.01314236096391534, max_bin=None,
#                                max_cat_threshold=None, max_cat_to_onehot=None,
#                                max_delta_step=None, max_depth=10,
#                                max_leaves=None, min_child_weight=None,
#                                missing=nan, monotone_constraints=None,
#                                multi_strategy=None, n_estimators=268,
#                                n_jobs=None, num_parallel_tree=None,
#                                random_state=42, ...))])

# %%
val = pd.read_csv("validation_set.csv")
val = create_features(val)
X_val = val[features]
y_pred_prob = final_model.predict_proba(X_val)[:, 1]

if "berlangganan_deposito" in val.columns:
    y_val = val["berlangganan_deposito"]
    fpr, tpr, _ = roc_curve(y_val, y_pred_prob)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(6, 4))
    plt.plot(fpr, tpr, label=f"ROC AUC = {roc_auc:.4f}")
    plt.plot([0, 1], [0, 1], "k--")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve")
    plt.legend()
    plt.grid(True)
    plt.show()

    # Precision-Recall Curve
    precision, recall, _ = precision_recall_curve(y_val, y_pred_prob)
    plt.figure(figsize=(6, 4))
    plt.plot(recall, precision, label="PR Curve")
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.title("Precision-Recall Curve")
    plt.grid(True)
    plt.show()
else:
    print("Kolom 'berlangganan_deposito' tidak tersedia pada validation set. Melewati evaluasi ROC/PR.")
# Out:
# Kolom 'berlangganan_deposito' tidak tersedia pada validation set. Melewati evaluasi ROC/PR.

# %%
submission = pd.DataFrame({
    "customer_number": val["customer_number"],
    "berlangganan_deposito": y_pred_prob
})
submission.to_csv("submission.csv", index=False)
